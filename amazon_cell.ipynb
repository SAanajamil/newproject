# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
amazon_cell = pd.read_csv("amazon_cell.csv")
amazon_cell
# Out:
#            asin     brand                                              title  \
# 0    B0000SX2UC     Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1    B0009N5L7K  Motorola                                Motorola I265 phone
# 2    B000SKTZ0S  Motorola  MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...
# 3    B00198M12M     Nokia  Nokia 6500 Slide Black/silver Unlocked Cell Phone
# 4    B001AO4OUC  Motorola              Motorola i335 Cell Phone Boost Mobile
# 5    B001DCJAJG  Motorola      Motorola V365 no contract cellular phone AT&T
# 6    B001DZY4KI      Sony  Sony Ericsson G700 Triband GSM Phone Bronze (U...
# 7    B001GQ3DJM     Nokia                  Nokia 1680 Black Phone (T-Mobile)
# 8    B0027VKQPE     Nokia                        Nokia New 1100 for Tracfone
# 9    B00280QJFU   Samsung             Samsung T301G Prepaid Phone (Tracfone)
# 10   B0029X7UHC  Motorola              Motorola I205 cell phone nextel/Boost
# ...

# %%
amazon_cell.describe
# Out:
# <bound method NDFrame.describe of            asin     brand                                              title  \
# 0    B0000SX2UC     Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1    B0009N5L7K  Motorola                                Motorola I265 phone
# 2    B000SKTZ0S  Motorola  MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...
# 3    B00198M12M     Nokia  Nokia 6500 Slide Black/silver Unlocked Cell Phone
# 4    B001AO4OUC  Motorola              Motorola i335 Cell Phone Boost Mobile
# 5    B001DCJAJG  Motorola      Motorola V365 no contract cellular phone AT&T
# 6    B001DZY4KI      Sony  Sony Ericsson G700 Triband GSM Phone Bronze (U...
# 7    B001GQ3DJM     Nokia                  Nokia 1680 Black Phone (T-Mobile)
# 8    B0027VKQPE     Nokia                        Nokia New 1100 for Tracfone
# 9    B00280QJFU   Samsung             Samsung T301G Prepaid Phone (Tracfone)
# 10   B0029X7UHC  Motorola              Motorola I205 cell phone nextel/Boost
# ...

# %%
amazon_cell.info
# Out:
# <bound method DataFrame.info of            asin     brand                                              title  \
# 0    B0000SX2UC     Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1    B0009N5L7K  Motorola                                Motorola I265 phone
# 2    B000SKTZ0S  Motorola  MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...
# 3    B00198M12M     Nokia  Nokia 6500 Slide Black/silver Unlocked Cell Phone
# 4    B001AO4OUC  Motorola              Motorola i335 Cell Phone Boost Mobile
# 5    B001DCJAJG  Motorola      Motorola V365 no contract cellular phone AT&T
# 6    B001DZY4KI      Sony  Sony Ericsson G700 Triband GSM Phone Bronze (U...
# 7    B001GQ3DJM     Nokia                  Nokia 1680 Black Phone (T-Mobile)
# 8    B0027VKQPE     Nokia                        Nokia New 1100 for Tracfone
# 9    B00280QJFU   Samsung             Samsung T301G Prepaid Phone (Tracfone)
# 10   B0029X7UHC  Motorola              Motorola I205 cell phone nextel/Boost
# ...

# %%
amazon_cell.shape
# Out:
# (792, 9)

# %%
amazon_cell.columns
# Out:
# Index(['asin', 'brand', 'title', 'url', 'image', 'rating', 'reviewUrl',
#        'totalReviews', 'prices'],
#       dtype='object')

# %%
amazon_cell['brand'].unique()
# Out:
# array(['Nokia', 'Motorola', 'Sony', 'Samsung', 'HUAWEI', 'Apple',
#        'OnePlus', 'Google', 'ASUS', 'Xiaomi'], dtype=object)

# %%
amazon_cell.isnull().sum()
# Out:
# asin              0
# brand             0
# title             0
# url               0
# image             0
# rating            0
# reviewUrl         0
# totalReviews      0
# prices          215
# dtype: int64

# %%
#fill NaN by values
amazon_cell = amazon_cell.bfill()
amazon_cell
# Out:
#            asin     brand                                              title  \
# 0    B0000SX2UC     Nokia  Dual-Band / Tri-Mode Sprint PCS Phone w/ Voice...
# 1    B0009N5L7K  Motorola                                Motorola I265 phone
# 2    B000SKTZ0S  Motorola  MOTOROLA C168i AT&T CINGULAR PREPAID GOPHONE C...
# 3    B00198M12M     Nokia  Nokia 6500 Slide Black/silver Unlocked Cell Phone
# 4    B001AO4OUC  Motorola              Motorola i335 Cell Phone Boost Mobile
# 5    B001DCJAJG  Motorola      Motorola V365 no contract cellular phone AT&T
# 6    B001DZY4KI      Sony  Sony Ericsson G700 Triband GSM Phone Bronze (U...
# 7    B001GQ3DJM     Nokia                  Nokia 1680 Black Phone (T-Mobile)
# 8    B0027VKQPE     Nokia                        Nokia New 1100 for Tracfone
# 9    B00280QJFU   Samsung             Samsung T301G Prepaid Phone (Tracfone)
# 10   B0029X7UHC  Motorola              Motorola I205 cell phone nextel/Boost
# ...

# %%
#find out the null value
amazon_cell.isnull().sum()
# Out:
# asin            0
# brand           0
# title           0
# url             0
# image           0
# rating          0
# reviewUrl       0
# totalReviews    0
# prices          0
# dtype: int64

# %%
amazon_cell.groupby("brand").count()
# Out:
#           asin  title  url  image  rating  reviewUrl  totalReviews  prices
# brand
# ASUS        13     13   13     13      13         13            13      13
# Apple      101    101  101    101     101        101           101     101
# Google      33     33   33     33      33         33            33      33
# HUAWEI      36     36   36     36      36         36            36      36
# Motorola   100    100  100    100     100        100           100     100
# Nokia       49     49   49     49      49         49            49      49
# OnePlus      7      7    7      7       7          7             7       7
# Samsung    397    397  397    397     397        397           397     397
# Sony        29     29   29     29      29         29            29      29
# Xiaomi      27     27   27     27      27         27            27      27

# %%
amazon_cell.groupby("brand").count()["rating"].sort_values()
# Out:
# brand
# OnePlus       7
# ASUS         13
# Xiaomi       27
# Sony         29
# Google       33
# HUAWEI       36
# Nokia        49
# Motorola    100
# Apple       101
# Samsung     397
# Name: rating, dtype: int64

# %%
# number of asin by Brand
plt.style.use("ggplot")
ax = amazon_cell.groupby("brand").count()["asin"].plot(kind="pie",
                                                         figsize=(8,11),
                                                        title = "Number of offering group by Brand")
plt.show()

# %%
#maximum Rating & Reviews
amazon_cell.max()
# Out:
# asin                                                   B07X51T2VK
# brand                                                      Xiaomi
# title                    iPhone 6S - 64GB (AT&T) - Rose (Renewed)
# url             https://www.amazon.com/iPhone-6S-64GB-Rose-Ref...
# image           https://m.media-amazon.com/images/I/A1S4AmmN0p...
# rating                                                          5
# reviewUrl       https://www.amazon.com/product-reviews/B07X51T2VK
# totalReviews                                                  984
# prices                                          $999.95,$1,349.99
# dtype: object

# %%
#minimum Rating and Reviews
amazon_cell.min()
# Out:
# asin                                                   B0000SX2UC
# brand                                                        ASUS
# title             APPLE iPhone 6S UNLOCKED - 16GB, Gold (Renewed)
# url             https://www.amazon.com/APPLE-iPhone-6S-UNLOCKE...
# image           https://m.media-amazon.com/images/I/210XRStw05...
# rating                                                          1
# reviewUrl       https://www.amazon.com/product-reviews/B0000SX2UC
# totalReviews                                                    1
# prices                                        $1,000.00,$1,399.99
# dtype: object

# %%
# Average Rating of Barnds
am = amazon_cell.groupby("brand").mean()["rating"].sort_values()
am
# Out:
# brand
# Nokia       3.322449
# OnePlus     3.342857
# Apple       3.527723
# Motorola    3.528000
# Samsung     3.573300
# Sony        3.731034
# Google      3.763636
# ASUS        3.776923
# HUAWEI      4.019444
# Xiaomi      4.337037
# Name: rating, dtype: float64

# %%
#Average Rating per Brand by bar chart
am = amazon_cell.groupby("brand").mean()["rating"].sort_values().plot(kind="barh",figsize=(8,5),title="Average Rating per Brand")
plt.show()

# %%
xiaomi = amazon_cell[(amazon_cell["brand"]=="Xiaomi")].head(27)
xiaomi
# Out:
#            asin   brand                                              title  \
# 544  B07D856BVR  Xiaomi  Xiaomi Redmi Note 5 64GB Dual Sim, Dual Camera...
# 558  B07F3YGL26  Xiaomi  Xiaomi Redmi S2 (32GB 3GB RAM) with AI Smart S...
# 564  B07FMPVBQR  Xiaomi  Xiaomi Mi A2 64GB + 4GB RAM, Dual Camera, LTE ...
# 574  B07G7JQCNX  Xiaomi  Xiaomi Mi A2 Lite 64GB + 4GB RAM, Dual Camera,...
# 576  B07G7QZKBG  Xiaomi  Xiaomi Redmi 6-64GB + 4GB RAM, Dual Camera, Du...
# 577  B07G8VPHG3  Xiaomi  Xiaomi Mi A2 Lite (64GB, 4GB RAM) 5.84" 18:9 H...
# 593  B07H41NB46  Xiaomi  Xiaomi Pocophone F1 128GB Graphite Black, Dual...
# 594  B07H7SBBWQ  Xiaomi  Xiaomi Redmi 6 - 64GB + 3GB RAM, Dual Camera, ...
# 606  B07HK4JNV1  Xiaomi  Xiaomi Redmi Note 6 Pro 64GB / 4GB RAM 6.26" D...
# 624  B07JMPGNHK  Xiaomi  Xiaomi Mi 8 Lite (64GB, 4GB RAM) 6.26" Full Sc...
# 638  B07K64PTLP  Xiaomi  Xiaomi Mi 8 Pro (128GB, 8GB RAM) with In-Scree...
# ...

# %%
xiaomi.drop(['asin', 'brand', 'title', 'url', 'image','reviewUrl','totalReviews', 'prices'],axis=1,inplace= True)
xiaomi
# Out:
#      rating
# 544     4.3
# 558     5.0
# 564     4.2
# 574     3.9
# 576     4.4
# 577     4.3
# 593     4.4
# 594     4.0
# 606     4.3
# 624     4.5
# 638     4.0
# 682     4.2
# 707     3.8
# 725     4.7
# 726     4.4
# 731     4.4
# 734     4.5
# 736     4.5
# 743     4.6
# 744     4.5
# 745     4.2
# 756     4.6
# 757     4.6
# 770     4.2
# 777     4.5
# 783     4.1
# 784     4.0

# %%
xiaomi = xiaomi.loc[::-1].reset_index(drop=True)
xiaomi
# Out:
#     rating
# 0      4.0
# 1      4.1
# 2      4.5
# 3      4.2
# 4      4.6
# 5      4.6
# 6      4.2
# 7      4.5
# 8      4.6
# 9      4.5
# 10     4.5
# 11     4.4
# 12     4.4
# 13     4.7
# 14     3.8
# 15     4.2
# 16     4.0
# 17     4.5
# 18     4.3
# 19     4.0
# 20     4.4
# 21     4.3
# 22     4.4
# 23     3.9
# 24     4.2
# 25     5.0
# 26     4.3

# %%
samsung = amazon_cell[(amazon_cell["brand"]=="Samsung")].head(27)
samsung
# Out:
#           asin    brand                                              title  \
# 9   B00280QJFU  Samsung             Samsung T301G Prepaid Phone (Tracfone)
# 11  B002AS9WEA  Samsung                Samsung a167 Prepaid GoPhone (AT&T)
# 13  B003FCO9XE  Samsung  Samsung Smooth Verizon Wireless Prepaid Mobile...
# 14  B003MW0OIQ  Samsung                Samsung a107 Prepaid GoPhone (AT&T)
# 15  B003P2VNAQ  Samsung                     Samsung Rugby II, Black (AT&T)
# 17  B003XREZ4O  Samsung            Samsung Gusto, Black (Verizon Wireless)
# 18  B004C7NVD0  Samsung  Samsung Convoy SCH-U640 Cell Phone Ruggedized ...
# 19  B004GLQTG8  Samsung                     Samsung R355C Net 10 Unlimited
# 20  B004H23JXW  Samsung  Samsung Focus I917 Unlocked Phone with Windows...
# 21  B004UVR9A4  Samsung        Samsung Factor Prepaid Phone (Boost Mobile)
# 23  B004YBP8EY  Samsung  Samsung SA-S5260WESP Cellphone - Unlocked Phon...
# ...

# %%
samsung.drop(['asin', 'brand', 'title', 'url', 'image','reviewUrl','totalReviews', 'prices'],axis=1,inplace= True)
samsung
# Out:
#     rating
# 9      3.5
# 11     2.9
# 13     2.8
# 14     2.6
# 15     3.2
# 17     2.0
# 18     3.4
# 19     3.5
# 20     3.4
# 21     3.4
# 23     3.1
# 25     3.5
# 27     4.0
# 28     3.5
# 29     3.1
# 30     2.5
# 31     2.8
# 32     3.5
# 33     3.6
# 34     3.5
# 35     3.6
# 36     3.5
# 40     2.9
# 45     2.6
# 49     3.7
# 50     3.8
# 55     3.4

# %%
samsung =  samsung.loc[::-1].reset_index(drop=True)
samsung
# Out:
#     rating
# 0      3.4
# 1      3.8
# 2      3.7
# 3      2.6
# 4      2.9
# 5      3.5
# 6      3.6
# 7      3.5
# 8      3.6
# 9      3.5
# 10     2.8
# 11     2.5
# 12     3.1
# 13     3.5
# 14     4.0
# 15     3.5
# 16     3.1
# 17     3.4
# 18     3.4
# 19     3.5
# 20     3.4
# 21     2.0
# 22     3.2
# 23     2.6
# 24     2.8
# 25     2.9
# 26     3.5

# %%
xiaomi= xiaomi.add_prefix("Xiaomi_")

# %%
samsung= samsung.add_prefix("Samsung_")

# %%
ax = pd.concat([xiaomi,samsung],axis=1)
ax
# Out:
#     Xiaomi_rating  Samsung_rating
# 0             4.0             3.4
# 1             4.1             3.8
# 2             4.5             3.7
# 3             4.2             2.6
# 4             4.6             2.9
# 5             4.6             3.5
# 6             4.2             3.6
# 7             4.5             3.5
# 8             4.6             3.6
# 9             4.5             3.5
# 10            4.5             2.8
# 11            4.4             2.5
# 12            4.4             3.1
# 13            4.7             3.5
# 14            3.8             4.0
# 15            4.2             3.5
# 16            4.0             3.1
# 17            4.5             3.4
# 18            4.3             3.4
# 19            4.0             3.5
# 20            4.4             3.4
# 21            4.3             2.0
# 22            4.4             3.2
# 23            3.9             2.6
# 24            4.2             2.8
# 25            5.0             2.9
# ...

# %%
ax.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000025FA6E1DFD0>,
# ...
#       dtype=object)
